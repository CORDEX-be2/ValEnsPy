# %%
import xarray as xr

# %%
ds = xr.open_dataset('/dodrio/scratch/projects/2022_200/project_output/rcs/CORDEXBE2/fiens/CB2_CCLM_BEL28_ERA5_evaluation/cclm/out/out02/lffd19971001010000.nc')

# %%
ds['T_2M'].plot()
