# %% [markdown]
# # CF checker
#
# A short illustration of what is currently checked by the CF (Climate and Forecast) conventions checker implemented in Valenspy.

# %%
import valenspy as vp
import xarray as xr
from pathlib import Path

from valenspy import is_cf_compliant, cf_status

# %% [markdown]
# ## What is checked?
#
# In Valenspy, the self implemented CF conventions checker checks the following:
#
# - The global attributes `history` and `Conventions` are present.
# - Checks if `time` is a dimension and is of the type `datetime64`.
# - Per variable the attributes `standard_name`, `long_name` & `units` are present.
# - Checks if the file is a netCDF file.
#
# In addition the cf_checker compares the variables in the file with the CORDEX_variables.yml file.
# If the variable is in the CORDEX_variables.yml file, the checker will check if the variable has the correct attributes.

# %% [markdown]
# ## Some examples
# These examples only work on the VSC cluster.
# ### CF compliant file
# Starting with a netCDF compliant file.
# Note that the is_cf_compliant function accepts a file path or an xarray dataset.

# %%
ds =  vp.InputManager(machine='hortense').load_data("ERA5",["tas"], period=[2000],freq="daily",region="europe", path_identifiers=["min"])
ds
# Out:
# File paths found:
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/daily/2m_temperature/era5-daily_min-europe-2m_temperature-2000.nc
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/2m_temperature/daily/era5-daily-europe-2m_temperature_min-2000.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ds =  vp.InputManager(machine='hortense').load_data("ERA5",["tas"], period=[2000],freq="daily",region="europe", path_identifiers=["min"])
#       2 ds
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/input/manager.py:169, in InputManager.load_data(self, dataset_name, variables, period, freq, region, cf_convert, path_identifiers, metadata_info)
#     167     if path_identifiers:
#     168         metadata_info["path_identifiers"] = path_identifiers
# --> 169     ds = input_converter.convert_input(files, metadata_info=metadata_info)
#     170 else:
#     171     ds = xr.open_mfdataset(files, chunks="auto")
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/input/converter.py:42, in InputConverter.convert_input(self, data_sources, metadata_info)
#      29 def convert_input(self, data_sources, metadata_info=None):
#      30     """Convert the input file(s)/xarray dataset to CF convention.
#      31
#      32     Parameters
#    (...)
#      40         An xarray dataset in CF convention.
#      41     """
# ---> 42     ds = load_xarray_from_data_sources(data_sources)
#      43     return self.converter(ds, metadata_info)
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/_utilities/_utilities.py:22, in load_xarray_from_data_sources(data_sources)
#       7 """Return a xarray dataset from an list of input files (Path objects), a single input file (Path object) or a xarray dataset.
#       8 This utility function enables the user to input different types of inputs which are then converted to a xarray dataset.
#       9
#    (...)
#      18     An xarray dataset.
#      19 """
#      21 if isinstance(data_sources, Path) or isinstance(data_sources, list):
# ---> 22     ds = xr.open_mfdataset(data_sources, combine="by_coords", chunks="auto")
#      23 elif isinstance(data_sources, xr.Dataset):
#      24     ds = data_sources
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/backends/api.py:1105, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1092     combined = _nested_combine(
#    1093         datasets,
#    1094         concat_dims=concat_dim,
#    (...)
#    1100         combine_attrs=combine_attrs,
#    1101     )
#    1102 elif combine == "by_coords":
#    1103     # Redo ordering from coordinates, ignoring how they were ordered
#    1104     # previously
# -> 1105     combined = combine_by_coords(
#    1106         datasets,
#    1107         compat=compat,
#    1108         data_vars=data_vars,
#    1109         coords=coords,
#    1110         join=join,
#    1111         combine_attrs=combine_attrs,
#    1112     )
#    1113 else:
#    1114     raise ValueError(
#    1115         f"{combine} is an invalid option for the keyword argument"
#    1116         " ``combine``"
#    1117     )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:958, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs)
#     954     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     956     # Perform the multidimensional combine on each group of data variables
#     957     # before merging back together
# --> 958     concatenated_grouped_by_data_vars = tuple(
#     959         _combine_single_variable_hypercube(
#     960             tuple(datasets_with_same_vars),
#     961             fill_value=fill_value,
#     962             data_vars=data_vars,
#     963             coords=coords,
#     964             compat=compat,
#     965             join=join,
#     966             combine_attrs=combine_attrs,
#     967         )
#     968         for vars, datasets_with_same_vars in grouped_by_vars
#     969     )
#     971 return merge(
#     972     concatenated_grouped_by_data_vars,
#     973     compat=compat,
#    (...)
#     976     combine_attrs=combine_attrs,
#     977 )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:959, in <genexpr>(.0)
#     954     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     956     # Perform the multidimensional combine on each group of data variables
#     957     # before merging back together
#     958     concatenated_grouped_by_data_vars = tuple(
# --> 959         _combine_single_variable_hypercube(
#     960             tuple(datasets_with_same_vars),
#     961             fill_value=fill_value,
#     962             data_vars=data_vars,
#     963             coords=coords,
#     964             compat=compat,
#     965             join=join,
#     966             combine_attrs=combine_attrs,
#     967         )
#     968         for vars, datasets_with_same_vars in grouped_by_vars
#     969     )
#     971 return merge(
#     972     concatenated_grouped_by_data_vars,
#     973     compat=compat,
#    (...)
#     976     combine_attrs=combine_attrs,
#     977 )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:645, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     643     indexes = concatenated.indexes.get(dim)
#     644     if not (indexes.is_monotonic_increasing or indexes.is_monotonic_decreasing):
# --> 645         raise ValueError(
#     646             "Resulting object does not have monotonic"
#     647             f" global indexes along dimension {dim}"
#     648         )
#     650 return concatenated
#
# ValueError: Resulting object does not have monotonic global indexes along dimension time

# %%
is_cf_compliant(ds) # A path or a dataset can be passed - here we pass the path
# Out:
# True

# %%
cf_status(ds) # A path or a dataset can be passed - here we pass the dataset
# Out:
# The file is ValEnsPy CF compliant.
# 50.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['ts']
# Unknown to ValEnsPy: ['time_bnds']

# %% [markdown]
# ### Non-CF compliant file
# The next examples include files which are not (completely) CF compliant.

# %%
is_cf_compliant('file_that_does_not_exist.nc') #Any file which is not a netCDF file (no .nc extension and cannot be loaded as an xarray) will return False - even if it does not exist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 is_cf_compliant('file_that_does_not_exist.nc') #Any file which is not a netCDF file (no .nc extension and cannot be loaded as an xarray) will return False - even if it does not exist
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/_utilities/cf_checks.py:97, in is_cf_compliant(netCDF, verbose)
#      67 def is_cf_compliant(netCDF: Union[str, Path, xr.Dataset], verbose=False) -> bool:
#      68     """
#      69     Check if a file is a ValEnsPy CF compliant netCDF file. The following checks are performed:
#      70     - Check if the file is a netCDF file (or an xarray dataset)
#    (...)
#      95
#      96     """
# ---> 97     ds = load_xarray_from_data_sources(netCDF)
#      99     var_meta_data_ok = all(
#     100         [
#     101             _check_variable_metadata(ds[var])
#    (...)
#     104         ]
#     105     )
#     106     main_meta_data_ok = _check_main_metadata(ds)
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/_utilities/_utilities.py:26, in load_xarray_from_data_sources(data_sources)
#      24     ds = data_sources
#      25 else:
# ---> 26     raise TypeError(
#      27         "The input should be a Path, a list of Paths or an xarray dataset."
#      28     )
#      29 return ds
#
# TypeError: The input should be a Path, a list of Paths or an xarray dataset.

# %% [markdown]
# E-OBS temperature file data set - directly loaded from file without the [input manager](input_manager.ipynb) and hence without an [input convertor](input_convertors.ipynb).

# %%
eobs = xr.open_dataset(Path("/dodrio/scratch/projects/2022_200/project_input/External/observations/EOBS/0.1deg/tg_ens_mean_0.1deg_reg_v29.0e.nc"), chunks={'time': 100})
eobs
# Out:
# <xarray.Dataset> Size: 35GB
# Dimensions:    (latitude: 465, longitude: 705, time: 27028)
# Coordinates:
#   * latitude   (latitude) float64 4kB 25.05 25.15 25.25 ... 71.25 71.35 71.45
#   * longitude  (longitude) float64 6kB -24.95 -24.85 -24.75 ... 45.35 45.45
#   * time       (time) datetime64[ns] 216kB 1950-01-01 1950-01-02 ... 2023-12-31
# Data variables:
#     tg         (time, latitude, longitude) float32 35GB dask.array<chunksize=(100, 465, 705), meta=np.ndarray>
# Attributes:
#     E-OBS_version:  29.0e
#     Conventions:    CF-1.4
#     References:     http://surfobs.climate.copernicus.eu/dataaccess/access_eo...
#     history:        Fri Mar 22 09:55:59 2024: ncks --no-abc -d time,0,27027 /...
#     NCO:            netCDF Operators version 5.1.4 (Homepage = http://nco.sf....

# %%
cf_status(eobs)
# Out:
# The file is ValEnsPy CF compliant.
# 0.00% of the variables are ValEnsPy CF compliant
# Unknown to ValEnsPy: ['tg']

# %% [markdown]
# It seems that E-OBS files is also CF compliant! However, currently the two datasets both contain temperature data but are not comparable, tg is unuseable within Valenspy. The E-OBS data set passed the is_cf_compliant function becuase tg is not in the CORDEX_variables.yml file. To be able to use the tg and compare it to our demo_data, E-OBS data should be translated to the CORDEX standard:

# %%
eobs =  vp.InputManager(machine='hortense').load_data("EOBS",["tas"], path_identifiers=["mean"])
eobs
# Out:
# File paths found:
# /dodrio/scratch/projects/2022_200/project_input/External/observations/EOBS/0.1deg/tg_ens_mean_0.1deg_reg_v29.0e.nc
# The file is ValEnsPy CF compliant.
# 100.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['tas']
# <xarray.Dataset> Size: 35GB
# Dimensions:  (lat: 465, lon: 705, time: 27028)
# Coordinates:
#   * lat      (lat) float64 4kB 25.05 25.15 25.25 25.35 ... 71.25 71.35 71.45
#   * lon      (lon) float64 6kB -24.95 -24.85 -24.75 -24.65 ... 45.25 45.35 45.45
#   * time     (time) datetime64[ns] 216kB 1950-01-01 1950-01-02 ... 2023-12-31
# Data variables:
#     tas      (time, lat, lon) float32 35GB dask.array<chunksize=(102, 465, 705), meta=np.ndarray>
# Attributes:
#     E-OBS_version:     29.0e
#     Conventions:       CF-1.4
#     References:        http://surfobs.climate.copernicus.eu/dataaccess/access...
#     history:           Fri Mar 22 09:55:59 2024: ncks --no-abc -d time,0,2702...
#     NCO:               netCDF Operators version 5.1.4 (Homepage = http://nco....
#     period:            2000
#     freq:              daily
#     region:            europe
#     path_identifiers:  ['mean']
#     dataset:           EOBS

# %%
cf_status(eobs)
# Out:
# The file is ValEnsPy CF compliant.
# 100.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['pr']

# %% [markdown]
# Note that conversion from °C to K is also automatically done by the convertor.

# %% [markdown]
# ## Incorrect time dimension (and type) example

# %%
eobs_wrong = eobs.rename({'time': 'wrong_time'})

# %% [markdown]
# The dataset is now no longer CF compliant because the time dimension is not present.

# %%
if is_cf_compliant(eobs_wrong):
    print('The dataset is CF compliant')
else:
    cf_status(eobs_wrong)
# Out:
# Time dimension is missing or has an incorrect type
# The file is NOT ValEnsPy CF compliant.
# 100.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['tas']

# %% [markdown]
# Also the if the time dimension is present but not of the type `datetime64`, the dataset is not CF compliant. Here we illustrate this by setting the time dimension to a string/object type.

# %%
eobs_wrong = eobs_wrong.rename({'wrong_time': 'time'})
#Change the time format to cf_time
eobs_wrong['time'] = eobs_wrong['time'].dt.strftime('%Y-%m-%d')
print(eobs_wrong['time'].dtype, eobs_wrong['time'][0].values)
if is_cf_compliant(eobs_wrong):
    print('The dataset is CF compliant')
else:
    cf_status(eobs_wrong)
# Out:
# object 1950-01-01
# Time dimension is missing or has an incorrect type
# The file is NOT ValEnsPy CF compliant.
# 100.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['tas']
