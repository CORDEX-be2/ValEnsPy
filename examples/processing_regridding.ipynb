# %% [markdown]
# # Regridding example
#
# This example shows the regridding capabilities of Valenspy. We will regrid EOBS (0.1deg) to the coarser ERA5 grid as an example.

# %%
import valenspy as vp
from valenspy._utilities import load_yml
import xarray as xr
from pathlib import Path
import cdo

# %% [markdown]
# ## Load your data
# Here we load ERA-5 and CCLM data.
# ### ERA-5 Data

# %%
#ERA-5 data
manager = vp.InputManager(machine="hortense")
ds_era5 = manager.load_data("ERA5",["tas"], period=[1995,1995],freq="daily",region="europe", path_identifiers = ["-daily-"])
# Out:
# File paths found:
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/2m_temperature/daily/era5-daily-europe-2m_temperature_min-1995.nc
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/daily/2m_temperature/era5-daily-europe-2m_temperature-1995.nc
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/2m_temperature/daily/era5-daily-europe-2m_temperature-1995.nc
# /dodrio/scratch/projects/2022_200/project_input/External/observations/era5/europe/2m_temperature/daily/era5-daily-europe-2m_temperature_max-1995.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #ERA-5 data
#       2 manager = vp.InputManager(machine="hortense")
# ----> 3 ds_era5 = manager.load_data("ERA5",["tas"], period=[1995,1995],freq="daily",region="europe", path_identifiers = ["-daily-"])
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/input/manager.py:169, in InputManager.load_data(self, dataset_name, variables, period, freq, region, cf_convert, path_identifiers, metadata_info)
#     167     if path_identifiers:
#     168         metadata_info["path_identifiers"] = path_identifiers
# --> 169     ds = input_converter.convert_input(files, metadata_info=metadata_info)
#     170 else:
#     171     ds = xr.open_mfdataset(files, chunks="auto")
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/input/converter.py:42, in InputConverter.convert_input(self, data_sources, metadata_info)
#      29 def convert_input(self, data_sources, metadata_info=None):
#      30     """Convert the input file(s)/xarray dataset to CF convention.
#      31
#      32     Parameters
#    (...)
#      40         An xarray dataset in CF convention.
#      41     """
# ---> 42     ds = load_xarray_from_data_sources(data_sources)
#      43     return self.converter(ds, metadata_info)
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/ValEnsPy/src/valenspy/_utilities/_utilities.py:22, in load_xarray_from_data_sources(data_sources)
#       7 """Return a xarray dataset from an list of input files (Path objects), a single input file (Path object) or a xarray dataset.
#       8 This utility function enables the user to input different types of inputs which are then converted to a xarray dataset.
#       9
#    (...)
#      18     An xarray dataset.
#      19 """
#      21 if isinstance(data_sources, Path) or isinstance(data_sources, list):
# ---> 22     ds = xr.open_mfdataset(data_sources, combine="by_coords", chunks="auto")
#      23 elif isinstance(data_sources, xr.Dataset):
#      24     ds = data_sources
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/backends/api.py:1105, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1092     combined = _nested_combine(
#    1093         datasets,
#    1094         concat_dims=concat_dim,
#    (...)
#    1100         combine_attrs=combine_attrs,
#    1101     )
#    1102 elif combine == "by_coords":
#    1103     # Redo ordering from coordinates, ignoring how they were ordered
#    1104     # previously
# -> 1105     combined = combine_by_coords(
#    1106         datasets,
#    1107         compat=compat,
#    1108         data_vars=data_vars,
#    1109         coords=coords,
#    1110         join=join,
#    1111         combine_attrs=combine_attrs,
#    1112     )
#    1113 else:
#    1114     raise ValueError(
#    1115         f"{combine} is an invalid option for the keyword argument"
#    1116         " ``combine``"
#    1117     )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:958, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs)
#     954     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     956     # Perform the multidimensional combine on each group of data variables
#     957     # before merging back together
# --> 958     concatenated_grouped_by_data_vars = tuple(
#     959         _combine_single_variable_hypercube(
#     960             tuple(datasets_with_same_vars),
#     961             fill_value=fill_value,
#     962             data_vars=data_vars,
#     963             coords=coords,
#     964             compat=compat,
#     965             join=join,
#     966             combine_attrs=combine_attrs,
#     967         )
#     968         for vars, datasets_with_same_vars in grouped_by_vars
#     969     )
#     971 return merge(
#     972     concatenated_grouped_by_data_vars,
#     973     compat=compat,
#    (...)
#     976     combine_attrs=combine_attrs,
#     977 )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:959, in <genexpr>(.0)
#     954     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     956     # Perform the multidimensional combine on each group of data variables
#     957     # before merging back together
#     958     concatenated_grouped_by_data_vars = tuple(
# --> 959         _combine_single_variable_hypercube(
#     960             tuple(datasets_with_same_vars),
#     961             fill_value=fill_value,
#     962             data_vars=data_vars,
#     963             coords=coords,
#     964             compat=compat,
#     965             join=join,
#     966             combine_attrs=combine_attrs,
#     967         )
#     968         for vars, datasets_with_same_vars in grouped_by_vars
#     969     )
#     971 return merge(
#     972     concatenated_grouped_by_data_vars,
#     973     compat=compat,
#    (...)
#     976     combine_attrs=combine_attrs,
#     977 )
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:619, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     613 if len(datasets) == 0:
#     614     raise ValueError(
#     615         "At least one Dataset is required to resolve variable names "
#     616         "for combined hypercube."
#     617     )
# --> 619 combined_ids, concat_dims = _infer_concat_order_from_coords(list(datasets))
#     621 if fill_value is None:
#     622     # check that datasets form complete hypercube
#     623     _check_shape_tile_ids(combined_ids)
#
# File /dodrio/scratch/projects/2022_200/project_output/RMIB-UGent/vsc46032_kobe/valenspy_dev/lib/python3.9/site-packages/xarray/core/combine.py:144, in _infer_concat_order_from_coords(datasets)
#     139             tile_ids = [
#     140                 tile_id + (position,) for tile_id, position in zip(tile_ids, order)
#     141             ]
#     143 if len(datasets) > 1 and not concat_dims:
# --> 144     raise ValueError(
#     145         "Could not find any dimension coordinates to use to "
#     146         "order the datasets for concatenation"
#     147     )
#     149 combined_ids = dict(zip(tile_ids, datasets))
#     151 return combined_ids, concat_dims
#
# ValueError: Could not find any dimension coordinates to use to order the datasets for concatenation

# %% [markdown]
# ### EOBS data

# %%
manager = vp.InputManager(machine="hortense")
ds_eobs = manager.load_data("EOBS",["tas"], path_identifiers = ["0.1deg",  "mean"])

# select 1995
ds_eobs = ds_eobs.sel(time=ds_eobs.time.dt.year.isin(1995))
# Out:
# File paths found:
# /dodrio/scratch/projects/2022_200/project_input/External/observations/EOBS/0.1deg/tg_ens_mean_0.1deg_reg_v29.0e.nc
# The file is ValEnsPy CF compliant.
# 100.00% of the variables are ValEnsPy CF compliant
# ValEnsPy CF compliant: ['tas']

# %% [markdown]
# # Regridding
# Now we can regrid the EOBS data to the ERA-5 grid. Here we use CDO. To make the workflow easier, we will use the CDO Python bindings to do this. A ValEnsPy function has been added to simplify this even further.
#
# ### Loading the CDO module
# First we need to load the CDO module as this is not installed in the environment by default. On most systems this can be done by running `module load CDO` in the terminal.
#
# To use it in the notebook as illustrated below you need to `module load CDO` in the terminal before starting the vscode server in the same terminal.
#
# Loading the module in the notebook itself will not work. On the vsc I have added `module load CDO` to the `~/.bashrc` file so it is loaded automatically when starting the server. Not ideal but it works until the VSC dashboard allows to add code before starting the vscode server.
#
# Alternatively you can install CDO in your python environment, but this is not supported in the Valenspy environment
#
# Another workaround is using python files. Try to run the following in a terminal with the CDO module loaded. This will give the same result as this notebook.
# ```bash
# python regridding_example.py
# ```
#
# If CDO is loaded `!which cdo` should return the path to the cdo executable.

# %%
# !which cdo #Check if the cdo module is loaded (If this does not provide a path, you need to load the cdo module)
# Out:
# /dodrio/scratch/projects/2022_200/RCS/CORDEXBE2/innev/miniconda3/envs/env_geo/bin/cdo

# %% [markdown]
# Now let's regrid the data. Note that the gridfile can be:
# - a path to a .nc file with the target grid
# - a string with the target grid name (e.g. 'r360x180') for a global regular grid
# - a path to a grid description file (e.g. a .txt file with the grid description)
#
# See cdo documentation for more information on the grid description file: https://code.mpimet.mpg.de/projects/cdo/embedded/cdo.pdf

# %%
# get an example ERA5 file to serve as target grid for the remapping function
gridfile = manager._get_file_paths('ERA5', "tas", period=[1995, 1995], freq="daily", region="europe", path_identifiers = ["-daily-"])[0]


from valenspy.preprocessing_tasks.regrid import remap_cdo

# do conditional remapping
ds_eobs_regrid = remap_cdo(gridfile, ds_eobs, remap_method="con")

# %% [markdown]
# Note that the data to be regridded and the regridded output data remains in xarray format. However, the target grid cannot be an xarray dataset but must be a path to a .nc file or other valid grid description.

# %% [markdown]
# # Plotting
# Finally we can plot the difference and see if the regridding worked as expected. Or other nicer diagnostics can be applied.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ds_era5["tas"].mean("time").plot(ax=ax[0])
ds_eobs_regrid["tas"].mean("time").plot(ax=ax[1])
(ds_era5["tas"].mean("time")-ds_eobs_regrid["tas"].mean("time")).plot(ax=ax[2])
fig.tight_layout()
